# %% [markdown]
# # Exploratory Data Analysis
# * Using Python to perform Exploratory Data Analysis
# on the "IT Salary Survey for EU region(2018-2020) dataset"
#
# ## About datasets
# * An anonymous salary survey has been conducted annually since 2015 among European IT specialists with a stronger focus on Germany. This year 1238 respondents volunteered to participate in the survey. The data has been made publicly available by the authors.
# The dataset contains rich information about the salary patterns among the IT professionals in the EU region and offers some great insights.
#
# * An accompanying article - [IT Salary Survey December 2020](https://www.asdcode.de/2021/01/it-salary-survey-december-2020.html) has also been published which goes deeper into the findings.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import  seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# * "%matplotlib inline" makes life easier by returning output plots  without needing to write plt.show() code everytime after each plot

# %% [markdown]
# ### Loading dataset
# * Downloaded the data set from Kaggle using [this](https://www.kaggle.com/datasets/parulpandey/2020-it-salary-survey-for-eu-region?resource=download) link
# * I saved the downloaded file in the same directory as my notebook
# * The downloaded file was in an csvformat, therefore I was able to load it on Microsoft Excel

# %%
df = pd.read_csv('IT Salary Survey EU  2020.csv', sep=',')
df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %% [markdown]
# * Original data is separated by the delimiter "," in the given dataset
# * `df.head` displays the first five rows of the data. You can adjust the number of rows displayed by passing an integer argument to the `head()` function
# * **Note**: The pandas library can load various type of files just as we loaded a csv file, some of the methods used are:
#     * Excel file : `read_excel()`
#     * JSON file: `read_json()`
#     * SQL database: `read_sql()`
#     * Text file: `read_table()` (_Normally the text is tab separated_)

# %% [markdown]
# ### Data insights

# %%
df.shape
# Out:
# (1253, 23)

# %% [markdown]
# * The dataset comprises of 1253 observations (_shown by rows_) and  23 characteristics (_shown by columns_)

# %%
df.columns.values
# Out:
# array(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status',
#        'Сontract duration', 'Main language at work', 'Company size',
#        'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
# ...

# %% [markdown]
# * Label of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %% [markdown]
# * The data has float and object types
# * No variable is null

# %% [markdown]
# ### Summary characteristics

# %%
df.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %% [markdown]
# **Key Observation**
# * For the Age variable, the mean is 32.5, with a standard deviation of 5.7. The youngest person in the data set is 20 years old, while the oldest is 69 years old.
#
# * For the Yearly brutto salary (without bonus and stocks) in EUR variable, the mean is 80,279 euros, with a standard deviation of 2,825,061 euros. The minimum salary reported is 10,001 euros, while the maximum is 100 billion euros, which may be an outlier.
#
# * For the Annual brutto salary (without bonus and stocks) one year ago variable, only 885 respondents who stayed in the same country reported their salary. The mean salary reported is 632,245 euros, with a standard deviation of 16,805,080 euros.
#
# * For the Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week variable, only 373 respondents reported that they were forced to have a shorter working week. The average number of hours per week was 12.97, with a standard deviation of 15.28. The maximum number of hours per week reported was 40.

# %% [markdown]
# ### Understanding Target Variable

# %%
df.Age.unique()
# Out:
# array([26., 29., 28., 37., 32., 24., 35., nan, 34., 31., 41., 27., 25.,
#        59., 36., 38., 40., 39., 33., 30., 49., 48., 44., 66., 45., 43.,
#        42., 46., 47., 56., 53., 65., 22., 23., 50., 51., 21., 20., 54.,
#        69., 52.])

# %% [markdown]
# * Target variable is continous in nature
# * The variables ranges from 20 to 69
# * There are some missing values for the variable indicated by `nan`

# %%
df.City.unique()
# Out:
# array(['Munich', 'Berlin', 'Hamburg', 'Wolfsburg', 'Stuttgart',
#        'Schleswig-Holstein', 'London', 'Konstanz area', 'Frankfurt',
#        'Cologne', 'Kempten', 'Münster', 'Erlangen', 'Vienna', 'Moldova',
#        'Rosenheim', 'Mannheim ', 'Boeblingen', 'Düsseldorf', 'Ingolstadt',
#        'Nürnberg', 'Ansbach', 'Leipzig', 'Mannheim', 'Tuttlingen', 'Bonn',
#        'Moscow', 'Koblenz', 'Warsaw', 'Heidelberg', 'Karlsruhe', 'Köln',
#        'Aachen', 'Karlsruhe ', 'Samara', 'Riga, Latvia', 'Dusseldorf',
#        'Zurich', 'Helsinki', 'Würzburg', 'Kiev', 'Den Haag', 'Amsterdam',
#        'Cracovia', 'Tallinn', 'Prague', 'Utrecht', 'Stockholm',
#        'Braunschweig ', 'Dresden', 'Kyiv', 'Stuttgart ', 'Malta',
#        'Lübeck', 'Nuremberg ', 'Bodensee', 'Milan', 'Salzburg', 'Rome',
#        'Wroclaw', 'Cupertino', 'Paris', 'Dublin ', 'Paderborn',
#        'Konstanz', 'Ulm', 'Düsseldorf ', 'Barcelona', 'Bölingen',
# ...

# %% [markdown]
# * The variable contains string objects

# %% [markdown]
# ### Data Visualization
# **To check missing values**

# %%
sns.heatmap(df.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# * This code snippet generates a heatmap using the Seaborn library to visualize the missing values in a Pandas DataFrame `df`.
#
# * The `df.isnull()` method returns a DataFrame of the same shape as the original df with True values where the data is missing (i.e., null or NaN values) and False values where the data is present.
#
# * The `sns.heatmap()` function takes this DataFrame and plots a heatmap where each cell is colored based on whether it contains a missing value or not. The `cbar=False` argument removes the color bar, `yticklabels=False` removes the y-axis labels, and `cmap='viridis'` sets the color map to be used.
#
# * By visualizing the missing values in this way, we can quickly identify patterns and clusters of missing data in the DataFrame.
#
# **From the above plot**
# * Some variables have null values while some like `city` do not

# %% [markdown]
# ### To check correlation

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df.corr(), cmap='Blues', annot=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# * Dark shades represents a positive correlation while the lighter shades represents negative correlation
# * If you annot = True you'll get values by which features are correlated to each other in grid-cells
# * **-Note(correlation)**: Correlation refers to the statistical relationship between two or more variables, indicating the degree to which they are related or co-vary. It measures the strength and direction of the linear relationship between two variables, ranging from -1 to +1. A correlation of +1 means that the two variables have a perfect positive relationship, i.e., as one variable increases, the other variable increases. A correlation of -1 means that the two variables have a perfect negative relationship, i.e., as one variable increases, the other variable decreases. A correlation of 0 means that there is no linear relationship between the two variables. Correlation is commonly used in data analysis and machine learning to understand the relationship between different variables and to identify patterns and trends in the data.

# %%
#Quallity of correlation matrix
k = 4 #number of variables for the heatmap
cols = df.corr().nlargest(k, 'Age')['Age'].index
cm = df[cols].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(cm, annot=True, cmap='Accent')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Challenges and summary
# * It was easy to load the data set after establishing the delimiting value for it.
# * It was hard to work with long column headings since they cannot fit properly on visualization diagrams.
