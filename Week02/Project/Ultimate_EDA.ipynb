# %% [markdown]
# # The Ultimate Exploratory Data Analysis
# For this task, I explored further the IT Salary Survey EU 2020.csv from week one.

# %% [markdown]
# ## Step 1. Importing Libraries and Loading Data
# * Import pandas
# * Import Numpy
# * Import Matplotlib
# * Import Seaborn
# * In addition import style to be used for plots to make them look nice(_Note that this is not compulsory_)

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %% [markdown]
# * To Load the dataset, download in in csv format.
# * Open the file and examine the data to establish the separator for the data columns
# * Save the dataset file in the same directory as that of the notebook

# %%
df = pd.read_csv('IT Salary Survey EU  2020.csv', sep=',')

# %% [markdown]
# ## Understanding the dataset
# After loading the dataset into a dataframe, it is good to explore it. We can find out the following about the data:
# * How many rows & columns does it have?
# * How does the first five and last five rows look like?
# * How are the columns labeled for this dataset?
# * What is the data type for each column?
# * What is the summary of statistical numerical analysis of the data e.g. mean, sd, ...?

# %%
df.shape
# Out:
# (1253, 23)

# %%
df.head(5)
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# 1                                        Ruby
# 2                     Javascript / Typescript
# 3                                  Javascript
# 4                                     C# .NET
#
#   Other technologies/programming languages you use often  ...  \
# 0                    Kotlin, Javascript / Typescript      ...
# 1                                                NaN      ...
# 2                    Javascript / Typescript, Docker      ...
# 3                                                NaN      ...
# 4                             .NET, SQL, AWS, Docker      ...
#
#    Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                              10000
# 1                                               5000
# 2                                             100000
# 3                                                NaN
# 4                                                NaN
#
#   Number of vacation days           Employment status   Сontract duration  \
# 0                      30          Full-time employee  Unlimited contract
# 1                      28          Full-time employee  Unlimited contract
# 2                      30  Self-employed (freelancer)  Temporary contract
# 3                      24          Full-time employee  Unlimited contract
# 4                      29          Full-time employee  Unlimited contract
#
#   Main language at work Company size Company type  \
# 0               English       51-100      Product
# 1               English     101-1000      Product
# 2               English     101-1000      Product
# 3               English       51-100      Startup
# 4               English     101-1000      Product
#
#   Have you lost your job due to the coronavirus outbreak?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
#        'Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                   object
# Age                                                                                                                        float64
# Gender                                                                                                                      object
# City                                                                                                                        object
# Position                                                                                                                    object
# Total years of experience                                                                                                   object
# Years of experience in Germany                                                                                              object
# Seniority level                                                                                                             object
# Your main technology / programming language                                                                                 object
# Other technologies/programming languages you use often                                                                      object
# Yearly brutto salary (without bonus and stocks) in EUR                                                                     float64
# Yearly bonus + stocks in EUR                                                                                                object
# Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country                   float64
# Annual bonus+stocks one year ago. Only answer if staying in same country                                                    object
# Number of vacation days                                                                                                     object
# Employment status                                                                                                           object
# Сontract duration                                                                                                           object
# Main language at work                                                                                                       object
# Company size                                                                                                                object
# Company type                                                                                                                object
# Have you lost your job due to the coronavirus outbreak?                                                                     object
# Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week                          float64
# Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR     object
# dtype: object

# %%
df.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# min                                         1.100000e+04
# 25%                                         5.500000e+04
# 50%                                         6.500000e+04
# 75%                                         7.500000e+04
# max                                         5.000000e+08
#
#        Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week
# count                                         373.000000
# mean                                           12.967828
# std                                            15.275174
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            30.000000
# max                                            40.000000

# %% [markdown]
# ## Cleaning data
# * Before running analysis on the data, it is wise to try and clean the data first. We can do the following:
# * Drop irrelevant columns i.e. columns not needed for analysis
# * Identify duplicated columns and rows
# * Rename columns to appropiate names, and remove whitespaces in column names

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
#        'Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR'],
#       dtype='object')

# %% [markdown]
# From this list of columns, those retained for the analysis are:
# * Age
# * Gender
# * City
# * Position
# * Total years of experience
# * Seniority level
# * Main technology/programming language
# * company size
# * company type
# * contract duration
# <br>
# To be able to do this, a subset dataframe of the original is made so as to solely focus analysis on this ten columns only. The dropped columns are commented out while forming the dataset to make it clearly visible, otherwise the drop method can be used.
# _The drop method is illustrated below but is commented out since it is not being used for the tutorial_

# %%
# Examples of dropping columns
#df.drop(['Years of experience in Germany'], axis=1)

# %%
df = df[[ 'Age', 'Gender', 'City', 'Position ',
       'Total years of experience', 'Сontract duration',
       #'Years of experience in Germany', 'Timestamp'
       'Seniority level', 'Your main technology / programming language',
       #'Other technologies/programming languages you use often',
       #'Yearly brutto salary (without bonus and stocks) in EUR',
       #'Yearly bonus + stocks in EUR',
       #'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
       #'Annual bonus+stocks one year ago. Only answer if staying in same country',
       #'Number of vacation days', 'Employment status',
       #'Main language at work', 
       'Company size', 'Company type',
       #'Have you lost your job due to the coronavirus outbreak?',
       #'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
       #'Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR'
    ]].copy()

# %%
df.shape
# Out:
# (1253, 10)

# %%
df.dtypes
# Out:
# Age                                            float64
# Gender                                          object
# City                                            object
# Position                                        object
# Total years of experience                       object
# Сontract duration                               object
# Seniority level                                 object
# Your main technology / programming language     object
# Company size                                    object
# Company type                                    object
# dtype: object

# %% [markdown]
# Next is to examine if the columns are of suitable data types.
# * The age column can be of int type
# * Total years of experience should be of int type
# <br>
# In addition we can rename our columns to more shorter and suitable versions while removing the whitespaces.

# %%
#df['Total years of experience'] = pd.to_numeric(df['Total years of experience'])
#df.dtypes

# %%
# Renamimng the columns
df = df.rename(columns={'Total years of experience':'Experience_in_years',
                  'Сontract duration':'Contract_duration',
                  'Seniority level':'Seniority_level',
                  'Your main technology / programming language':'Main_programming_language',
                  'Company size':'Company_size',
                  'Company type':'Company_type'})
df.columns
# Out:
# Index(['Age', 'Gender', 'City', 'Position ', 'Experience_in_years',
#        'Contract_duration', 'Seniority_level', 'Main_programming_language',
#        'Company_size', 'Company_type'],
#       dtype='object')

# %% [markdown]
# Next is to check for null values in our dataframe. This helps in giving a glimpse on how the null data is distributed among the selected columns in the subset dataframe.

# %%
df.isna().sum()
# Out:
# Age                           27
# Gender                        10
# City                           0
# Position                       6
# Experience_in_years           16
# Contract_duration             29
# Seniority_level               12
# Main_programming_language    127
# Company_size                  18
# Company_type                  25
# dtype: int64

# %% [markdown]
# The results shows that all columns apart from the city has null values.
# <br>
# Next is to look for duplicates within the dataset

# %%
df.loc[df.duplicated()].head(5)
# Out:
#       Age  Gender    City          Position  Experience_in_years  \
# 51   28.0  Female  Berlin   Designer (UI/UX)                   7
# 126  31.0    Male  Berlin  Software Engineer                   9
# 217  27.0    Male  Berlin  Backend Developer                   5
# 319  46.0    Male  Berlin  Software Engineer                  14
# 567  30.0    Male  Berlin    Product Manager                   3
#
#       Contract_duration Seniority_level Main_programming_language  \
# 51   Unlimited contract          Middle                     Figma
# 126  Unlimited contract          Senior             C#, .net core
# 217  Unlimited contract          Middle                      Java
# 319  Unlimited contract          Senior                JavaScript
# 567  Unlimited contract          Junior                       NaN
#
#     Company_size Company_type
# 51         1000+      Product
# 126        11-50      Startup
# 217        1000+      Product
# 319       51-100      Product
# 567        11-50      Product

# %%
df.duplicated(subset=['Age','Gender', 'City', 'Position ', 'Experience_in_years',
       'Contract_duration', 'Seniority_level', 'Main_programming_language',
       'Company_size', 'Company_type'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1248    False
# 1249    False
# 1250    False
# 1251    False
# 1252    False
# Length: 1253, dtype: bool

# %%
# Querrying one of the columns
df.query('Age==26.0')
# Out:
#        Age  Gender              City                         Position   \
# 0     26.0    Male            Munich                 Software Engineer
# 1     26.0    Male            Berlin                 Backend Developer
# 79    26.0  Female            Munich                    Data Scientist
# 80    26.0    Male            Berlin                 Software Engineer
# 100   26.0    Male            Munich                 Backend Developer
# 109   26.0    Male            Munich                    Data Scientist
# 123   26.0  Female            Munich                    Data Scientist
# 145   26.0    Male           Münster                    Data Scientist
# 188   26.0    Male            Berlin                  Mobile Developer
# 209   26.0    Male            Berlin                 Software Engineer
# 239   26.0  Female            Berlin                 Software Engineer
# 244   26.0    Male            Munich                       ML Engineer
# 317   26.0    Male         Frankfurt                        Consultant
# 325   26.0    Male         Frankfurt                 Backend Developer
# 344   26.0    Male         Frankfurt                 Software Engineer
# 357   26.0    Male         Karlsruhe                 Software Engineer
# 382   26.0    Male      Riga, Latvia                 Software Engineer
# 385   26.0    Male           Hamburg                 Software Engineer
# 425   26.0    Male            London                Frontend Developer
# 437   26.0    Male            Berlin                 Marketing Analyst
# 500   26.0  Female            Berlin                    Data Scientist
# 536   26.0    Male            Berlin                    Data Scientist
# 540   26.0    Male            Berlin                 Software Engineer
# 565   26.0    Male            Berlin                     Data Engineer
# 579   26.0  Female            Berlin                    Data Scientist
# 683   26.0    Male            Berlin                        Architect
# 713   26.0  Female        Dusseldorf  BI Consultant SAP/ Data Engineer
# 716   26.0    Male            London                            DevOps
# 725   26.0    Male            Berlin                     Data Engineer
# 758   26.0    Male            Berlin                 Backend Developer
# 776   26.0    Male            Berlin                    Data Scientist
# 817   26.0  Female            Moscow                Frontend Developer
# 830   26.0    Male            Berlin                 Software Engineer
# 834   26.0  Female            Berlin                   Tech recruiting
# 837   26.0    Male            Munich                       ML Engineer
# 839   26.0    Male         Eindhoven                       ML Engineer
# 881   26.0    Male            Berlin                    Data Scientist
# 924   26.0    Male            Berlin                 Backend Developer
# 925   26.0    Male         Amsterdam                    Data Scientist
# 931   26.0    Male            Berlin                 Software Engineer
# 934   26.0    Male            Berlin                 Backend Developer
# 943   26.0    Male            Lisbon                 Software Engineer
# 963   26.0    Male            Berlin                            DevOps
# 1002  26.0  Female            Berlin                 Backend Developer
# 1012  26.0    Male            Munich                 Software Engineer
# 1024  26.0  Female          Hannover                       QA Engineer
# 1028  26.0    Male            Berlin                       QA Engineer
# 1040  26.0  Female            Prague                 Software Engineer
# 1041  26.0    Male            Berlin                   Product Analyst
# 1053  26.0  Female            Berlin                 Backend Developer
# 1069  26.0    Male            Munich                 Software Engineer
# 1140  26.0  Female            Berlin                  Mobile Developer
# 1151  26.0    Male         Stockholm                       ML Engineer
# 1205  26.0    Male            Berlin                 Backend Developer
# 1219  26.0    Male            Munich                  Mobile Developer
# 1234  26.0    Male  Saint-Petersburg                   Project Manager
# 1235  26.0    Male  Saint-Petersburg                   Project Manager
# 1251  26.0    Male       Saarbrücken                Frontend Developer
# 1252  26.0    Male            Berlin                            DevOps
#
#      Experience_in_years   Contract_duration Seniority_level  \
# 0                      5  Unlimited contract          Senior
# 1                      7  Unlimited contract          Senior
# 79                     6  Unlimited contract          Middle
# 80                     8  Unlimited contract            Lead
# 100                    7  Unlimited contract          Senior
# 109                    3  Unlimited contract          Middle
# 123                    3  Unlimited contract          Junior
# 145                  5.5  Unlimited contract          Junior
# 188                    6  Unlimited contract          Senior
# 209                    5  Unlimited contract          Middle
# 239                    6  Unlimited contract          Senior
# 244                  1.5  Unlimited contract          Junior
# 317                    4  Unlimited contract          Middle
# 325                    7  Unlimited contract          Senior
# 344                    3  Unlimited contract          Middle
# 357                    5  Unlimited contract             NaN
# 382                    4  Unlimited contract          Middle
# 385                    7  Unlimited contract          Senior
# 425                    8  Unlimited contract          Senior
# 437                    7  Unlimited contract          Middle
# 500                    2  Unlimited contract          Junior
# 536                    5  Unlimited contract          Middle
# 540                    5  Unlimited contract          Middle
# 565                    2  Unlimited contract          Middle
# 579                    4  Temporary contract          Middle
# 683                    9  Unlimited contract            Head
# 713                    5  Unlimited contract          Middle
# 716                    3  Unlimited contract          Middle
# 725                    4  Unlimited contract          Middle
# 758                  2.5  Unlimited contract          Middle
# 776                    4  Unlimited contract          Middle
# 817                    6  Unlimited contract          Senior
# 830                    2  Unlimited contract          Middle
# 834                  2,5  Unlimited contract          Middle
# 837                    5  Temporary contract          Senior
# 839                    3  Unlimited contract          Middle
# 881                    2  Unlimited contract          Junior
# 924                    2  Unlimited contract          Junior
# 925                    2  Temporary contract          Junior
# 931                    5  Unlimited contract          Middle
# 934                    6  Unlimited contract          Senior
# 943                    4  Unlimited contract          Middle
# 963                    5  Unlimited contract          Middle
# 1002                   5  Unlimited contract          Middle
# 1012                   4  Unlimited contract          Middle
# 1024                   2  Unlimited contract          Middle
# 1028                   4                 NaN          Middle
# 1040                   4  Unlimited contract          Middle
# 1041                   4  Unlimited contract          Middle
# 1053                   7  Unlimited contract          Senior
# 1069                   6  Unlimited contract          Senior
# 1140                   8  Temporary contract          Middle
# 1151                 2.5  Unlimited contract          Middle
# 1205                   5  Unlimited contract          Middle
# 1219                   5  Unlimited contract          Middle
# 1234                   5  Unlimited contract          Middle
# 1235                   5  Unlimited contract          Middle
# 1251                   7  Unlimited contract          Middle
# 1252                   2  Unlimited contract          Middle
#
#                  Main_programming_language Company_size         Company_type
# 0                               TypeScript       51-100              Product
# 1                                     Ruby     101-1000              Product
# 79                                  python        1000+              Product
# 80                                      Go        1000+              Product
# 100                                   Java     101-1000              Product
# 109                                 Python     101-1000              Product
# 123                              Ml/Python        1000+              Product
# 145                                 Python        1000+              Product
# 188                                 Kotlin     101-1000              Product
# 209                                  Scala     101-1000              Product
# 239                                   .NET     101-1000              Product
# 244                                 Python     101-1000  Consulting / Agency
# 317                             JavaScript     101-1000  Consulting / Agency
# 325                                   Java     101-1000              Product
# 344                                Python        51-100  Consulting / Agency
# 357                                    NaN        11-50  Consulting / Agency
# 382                             javascript     101-1000  Consulting / Agency
# 385                             TypeScript     101-1000  Consulting / Agency
# 425                      TypeScript, React        1000+              Startup
# 437                                    SQL     101-1000              Startup
# 500                                 Python        11-50  Consulting / Agency
# 536                                Python      101-1000              Startup
# 540                                  Swift        1000+              Product
# 565                                 Python        1000+              Product
# 579              Sql, BQ, tableau, gtm, ga     101-1000              Startup
# 683                                     Go        1000+              Product
# 713                                   ABAP     up to 10              Startup
# 716   networking, linux, automation, cloud       51-100              Product
# 725                                  Scala        11-50  Consulting / Agency
# 758                                   Java     101-1000              Product
# 776                                 Python        1000+            Ecommerce
# 817                             JavaScript     101-1000              Product
# 830                             TypeScript        1000+  Consulting / Agency
# 834                                     JS     101-1000              Product
# 837                                  Spark     up to 10  Consulting / Agency
# 839                                 Python     101-1000              Product
# 881                                 Pyrhon        1000+                  NaN
# 924                                    Php        11-50              Product
# 925                                 Python       51-100              Fintech
# 931                        Python (Django)     101-1000              Product
# 934                                     Go        1000+              Product
# 943                             JavaScript       51-100              Product
# 963             Kubernetes, Terraform, GCP        11-50              Startup
# 1002                                  Java        1000+              Product
# 1012               JavaScript / TypeScript     101-1000              Startup
# 1024                       Tricentis Tosca        1000+      Non-tech retail
# 1028                          Swift/Kotlin       51-100              Startup
# 1040                                    C#        1000+              Product
# 1041                                Python        1000+              Product
# 1053                                   NaN     up to 10              Product
# 1069                            TypeScript        11-50              Startup
# 1140                                   c++     101-1000              Product
# 1151                            Python/NLP        1000+              Product
# 1205                                  Java        1000+              Product
# 1219                                Kotlin       51-100              Startup
# 1234                                Python        1000+              Product
# 1235                                Python        1000+              Product
# 1251                            JavaScript     101-1000              Product
# 1252                                  yaml       51-100              Startup

# %% [markdown]
# ## Feature Understanding
# Up next is to carry univariate analysis of features making up our dataframe subset.
# We will mostly use histogram to see the distribution of features independently

# %%
df.head(5)
# Out:
#     Age Gender    City           Position  Experience_in_years  \
# 0  26.0   Male  Munich   Software Engineer                   5
# 1  26.0   Male  Berlin   Backend Developer                   7
# 2  29.0   Male  Berlin   Software Engineer                  12
# 3  28.0   Male  Berlin  Frontend Developer                   4
# 4  37.0   Male  Berlin   Backend Developer                  17
#
#     Contract_duration Seniority_level Main_programming_language Company_size  \
# 0  Unlimited contract          Senior                TypeScript       51-100
# 1  Unlimited contract          Senior                      Ruby     101-1000
# 2  Temporary contract            Lead   Javascript / Typescript     101-1000
# 3  Unlimited contract          Junior                Javascript       51-100
# 4  Unlimited contract          Senior                   C# .NET     101-1000
#
#   Company_type
# 0      Product
# 1      Product
# 2      Product
# 3      Startup
# 4      Product

# %%
ax = df['Age'].plot(kind='hist', bins=20, title="Distribution of Age for Employees")
ax.set_xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# * Most of the employees employed in IT in Europe are around 30 years.
# * From the histogram we can also note that the distrubution of age ranges from 20 to almost 70 years
